# %% [markdown]
# <a href="https://colab.research.google.com/github/spouladchang/Deep-Q-Learning-Case-Study/blob/main/cT_13_miniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

# %%
env = gym.make('MountainCar-v0', render_mode = "rgb_array")
state, info = env.reset()

plt.imshow(env.render())
plt.axis('off')
plt.show()
plt.close()

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %% [markdown]
# min_position = -1.2
#
# max_position = 0.6
#
# min_speed = -0.07
#
# max_speed = 0.07

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
#     There are 3 discrete deterministic actions:
#
#     | Num | Observation             | Value | Unit         |
#     |-----|-------------------------|-------|--------------|
#     | 0   | Accelerate to the left  | Inf   | position (m) |
#     | 1   | Don't accelerate        | Inf   | position (m) |
#     | 2   | Accelerate to the right | Inf   | position (m) |

# %%
print(env.reset())
# Out:
# (array([-0.5872123,  0.       ], dtype=float32), {})

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML

num_games = 1
max_iterations = 200
rewards = []
frames = []
for episode in range(num_games):
    state, _ = env.reset()
    tot_rewards = 0
    for step in range(max_iterations):
        action = env.action_space.sample()
        next_state, reward, terminated, truncated, _ = env.step(action)
        frames.append(env.render())
        tot_rewards += reward

        if terminated or truncated:
            print(f"Game {episode} ended at step {step + 1 } with totla rewards {tot_rewards}.") # step + 1 for start from 0!
            break
    rewards.append(tot_rewards)
env.close()

def show_animation(frames):
    fig = plt.figure(figsize=(5, 4))
    plt.axis('off')
    im = plt.imshow(frames[0])

    def animate(i):
        im.set_array(frames[i])
        return [im]

    anim = animation.FuncAnimation(fig, animate, frames=len(frames), interval=50)
    plt.close()
    return HTML(anim.to_jshtml())

show_animation(frames)
# Out:
# Game 0 ended at step 200 with totla rewards -200.0.
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...
